# %% [markdown]
# # Extract from API - Transform -Load -InMemory DB
#
# #### Tinto T. Kurian   tthekkummuriyilkurian@my365.bellevue.edu

# %%
# Import necessary libraries
import pandas as pd
import requests
import json

# %%
url = "https://wind-bow.glitch.me/twitch-api/channels/freecodecamp"
JSONContent = requests.get(url).json()
content = json.dumps(JSONContent, indent = 4,sort_keys=True)
print(content)
# Out:
# {
#     "_id": 79776140,
#     "_links": {
#         "chat": "https://api.twitch.tv/kraken/chat/freecodecamp",
#         "commercial": "https://api.twitch.tv/kraken/channels/freecodecamp/commercial",
#         "editors": "https://api.twitch.tv/kraken/channels/freecodecamp/editors",
#         "follows": "https://api.twitch.tv/kraken/channels/freecodecamp/follows",
#         "self": "https://api.twitch.tv/kraken/channels/freecodecamp",
#         "stream_key": "https://api.twitch.tv/kraken/channels/freecodecamp/stream_key",
#         "subscriptions": "https://api.twitch.tv/kraken/channels/freecodecamp/subscriptions",
#         "teams": "https://api.twitch.tv/kraken/channels/freecodecamp/teams",
#         "videos": "https://api.twitch.tv/kraken/channels/freecodecamp/videos"
#     },
#     "background": null,
#     "banner": null,
#     "broadcaster_language": "en",
#     "created_at": "2015-01-14T03:36:47Z",
#     "delay": null,
#     "display_name": "FreeCodeCamp",
# ...

# %%
channels_list = []
# For each channel, we access its information through its API
for channel in channels:
    JSONContent = requests.get("https://wind-bow.glitch.me/twitch-api/channels/" + channel).json()
    if 'error' not in JSONContent:
        channels_list.append([JSONContent['_id'],
JSONContent['background'], 
JSONContent['banner'],
JSONContent['broadcaster_language'],
JSONContent['created_at'],
JSONContent['delay'],
JSONContent['display_name'], 
JSONContent['followers'],
JSONContent['game'],
JSONContent['language'],
JSONContent['logo'],
JSONContent['mature'],
JSONContent['name'],
JSONContent['partner'],
JSONContent['profile_banner'],
JSONContent['profile_banner_background_color'],
JSONContent['status'], 
JSONContent['updated_at'],
JSONContent['url'],
JSONContent['video_banner'], 
JSONContent['views']
])

# %%
dataset = pd.DataFrame(channels_list)
dataset.head()
# Out:
#          0     1     2     3                     4     5             6   \
# 0  30220059  None  None    en  2012-05-02T09:59:20Z  None       ESL_SC2
# 1  71852806  None  None    fr  2014-09-24T15:06:58Z  None    OgamingSC2
# 2  90401618  None  None    en  2015-05-06T15:57:39Z  None     cretetion
# 3  79776140  None  None    en  2015-01-14T03:36:47Z  None  FreeCodeCamp
# 4  86238744  None  None  None  2015-03-25T02:23:40Z  None      storbeck
#
#        7                          8   9   \
# 0  135394               StarCraft II  en
# 1   40895               StarCraft II  en
# 2     908  Tom Clancy's The Division  en
# 3   10122                   Creative  en
# 4      10                       None  en
#
#                         ...                                  12     13  \
# 0                       ...                             esl_sc2   True
# 1                       ...                          ogamingsc2   True
# ...

# %%
dataset.columns = ['Id',
'background', 
'banner',
'broadcaster_language',
'created_at',
'delay',
'display_name', 
'followers',
'game',
'language',
'logo',
'mature',
'name',
'partner',
'profile_banner',
'profile_banner_background_color',
'status', 
'updated_at',
'url',
'video_banner', 
'views']

# %% [markdown]
# Adding proper column names

# %%
dataset.head()
# Out:
#          Id background banner broadcaster_language            created_at  \
# 0  30220059       None   None                   en  2012-05-02T09:59:20Z
# 1  71852806       None   None                   fr  2014-09-24T15:06:58Z
# 2  90401618       None   None                   en  2015-05-06T15:57:39Z
# 3  79776140       None   None                   en  2015-01-14T03:36:47Z
# 4  86238744       None   None                 None  2015-03-25T02:23:40Z
#
#   delay  display_name  followers                       game language  \
# 0  None       ESL_SC2     135394               StarCraft II       en
# 1  None    OgamingSC2      40895               StarCraft II       en
# 2  None     cretetion        908  Tom Clancy's The Division       en
# 3  None  FreeCodeCamp      10122                   Creative       en
# 4  None      storbeck         10                       None       en
#
#                         ...                                name partner  \
# ...

# %%
len(dataset.index)
# Out:
# 8

# %%
dataset.dropna(axis = 0, how = 'all', inplace = True)

# %% [markdown]
# Dropping any rows that have null values for all the columns.

# %%
len(dataset.index)
# Out:
# 8

# %%
dataset
# Out:
#          Id background banner broadcaster_language            created_at  \
# 0  30220059       None   None                   en  2012-05-02T09:59:20Z
# 1  71852806       None   None                   fr  2014-09-24T15:06:58Z
# 2  90401618       None   None                   en  2015-05-06T15:57:39Z
# 3  79776140       None   None                   en  2015-01-14T03:36:47Z
# 4  86238744       None   None                 None  2015-03-25T02:23:40Z
# 5   6726509       None   None                 None  2009-06-07T15:04:54Z
# 6  54925078       None   None                   en  2014-01-13T04:07:33Z
# 7  82534701       None   None                   en  2015-02-13T08:13:10Z
#
#   delay  display_name  followers                       game language  \
# 0  None       ESL_SC2     135394               StarCraft II       en
# 1  None    OgamingSC2      40895               StarCraft II       en
# 2  None     cretetion        908  Tom Clancy's The Division       en
# ...

# %%
dataset.dropna(subset=['broadcaster_language'], inplace = True)

# %% [markdown]
# Dropping rows that have a null values in broadcaster_language

# %%
dataset
# Out:
#          Id background banner broadcaster_language            created_at  \
# 0  30220059       None   None                   en  2012-05-02T09:59:20Z
# 1  71852806       None   None                   fr  2014-09-24T15:06:58Z
# 2  90401618       None   None                   en  2015-05-06T15:57:39Z
# 3  79776140       None   None                   en  2015-01-14T03:36:47Z
# 6  54925078       None   None                   en  2014-01-13T04:07:33Z
# 7  82534701       None   None                   en  2015-02-13T08:13:10Z
#
#   delay  display_name  followers                       game language  \
# 0  None       ESL_SC2     135394               StarCraft II       en
# 1  None    OgamingSC2      40895               StarCraft II       en
# 2  None     cretetion        908  Tom Clancy's The Division       en
# 3  None  FreeCodeCamp      10122                   Creative       en
# 6  None    RobotCaleb         20                Programming       en
# ...

# %%
# List of channels we want to access
channels = ["ESL_SC2", "OgamingSC2", "cretetion", "freecodecamp", "storbeck", "habathcx", "RobotCaleb", "noobs2ninjas",
            "ninja", "shroud", "Dakotaz", "esltv_cs", "pokimane", "tsm_bjergsen", "boxbox", "wtcn", "a_seagull",
           "kinggothalion", "amazhs", "jahrein", "thenadeshot", "sivhd", "kingrichard"]

link_list = []
# For each channel, we access its information through its API
for channel in channels:
    JSONContent = requests.get("https://wind-bow.glitch.me/twitch-api/channels/" + channel).json()
    if 'error' not in JSONContent:
        link_list.append([JSONContent['_id'],
JSONContent['_links']['chat'],
JSONContent['_links']['commercial'],
JSONContent['_links']['editors'],
JSONContent['_links']['follows'],
JSONContent['_links']['self'],
JSONContent['_links']['stream_key'],
JSONContent['_links']['subscriptions'],
JSONContent['_links']['teams'],
JSONContent['_links']['videos']
                              
])

# %%
linkset = pd.DataFrame(link_list)
linkset.head()
# Out:
#           0                                               1  \
# 0  30220059       https://api.twitch.tv/kraken/chat/esl_sc2
# 1  71852806    https://api.twitch.tv/kraken/chat/ogamingsc2
# 2  90401618     https://api.twitch.tv/kraken/chat/cretetion
# 3  79776140  https://api.twitch.tv/kraken/chat/freecodecamp
# 4  86238744      https://api.twitch.tv/kraken/chat/storbeck
#
#                                                    2  \
# 0  https://api.twitch.tv/kraken/channels/esl_sc2/...
# 1  https://api.twitch.tv/kraken/channels/ogamings...
# 2  https://api.twitch.tv/kraken/channels/cretetio...
# 3  https://api.twitch.tv/kraken/channels/freecode...
# 4  https://api.twitch.tv/kraken/channels/storbeck...
#
#                                                    3  \
# 0  https://api.twitch.tv/kraken/channels/esl_sc2/...
# 1  https://api.twitch.tv/kraken/channels/ogamings...
# 2  https://api.twitch.tv/kraken/channels/cretetio...
# 3  https://api.twitch.tv/kraken/channels/freecode...
# ...

# %%
linkset.columns = ['Id',
'chat',
'commercial',
'editors',
'follows',
'self',
'stream_key',
'subscriptions',
'teams',
'videos']

# %% [markdown]
# Adding proper columns name

# %%
linkset.head()
# Out:
#          Id                                            chat  \
# 0  30220059       https://api.twitch.tv/kraken/chat/esl_sc2
# 1  71852806    https://api.twitch.tv/kraken/chat/ogamingsc2
# 2  90401618     https://api.twitch.tv/kraken/chat/cretetion
# 3  79776140  https://api.twitch.tv/kraken/chat/freecodecamp
# 4  86238744      https://api.twitch.tv/kraken/chat/storbeck
#
#                                           commercial  \
# 0  https://api.twitch.tv/kraken/channels/esl_sc2/...
# 1  https://api.twitch.tv/kraken/channels/ogamings...
# 2  https://api.twitch.tv/kraken/channels/cretetio...
# 3  https://api.twitch.tv/kraken/channels/freecode...
# 4  https://api.twitch.tv/kraken/channels/storbeck...
#
#                                              editors  \
# 0  https://api.twitch.tv/kraken/channels/esl_sc2/...
# 1  https://api.twitch.tv/kraken/channels/ogamings...
# 2  https://api.twitch.tv/kraken/channels/cretetio...
# 3  https://api.twitch.tv/kraken/channels/freecode...
# ...

# %%
df = pd.merge(dataset, linkset)

# %%
df
# Out:
#          Id background banner broadcaster_language            created_at  \
# 0  30220059       None   None                   en  2012-05-02T09:59:20Z
# 1  71852806       None   None                   fr  2014-09-24T15:06:58Z
# 2  90401618       None   None                   en  2015-05-06T15:57:39Z
# 3  79776140       None   None                   en  2015-01-14T03:36:47Z
# 4  86238744       None   None                 None  2015-03-25T02:23:40Z
# 5   6726509       None   None                 None  2009-06-07T15:04:54Z
# 6  54925078       None   None                   en  2014-01-13T04:07:33Z
# 7  82534701       None   None                   en  2015-02-13T08:13:10Z
#
#   delay  display_name  followers                       game language  \
# 0  None       ESL_SC2     135394               StarCraft II       en
# 1  None    OgamingSC2      40895               StarCraft II       en
# 2  None     cretetion        908  Tom Clancy's The Division       en
# ...

# %% [markdown]
# Merged the two data sets together using pandas merge function.

# %%
def store_in_db(item):
    db = dataset.connect('sqlite:///freecodecamp.db')
    table = db['freecodecamp']
    item_json = item._json.copy()
    for k, v in item_json.items():
        if isinstance(v, dict):
            item_json[k] = str(v)
    table.insert(item_json)

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite://', echo=False)

# %%
df.to_sql('freecodecamp', con=engine)

# %%
engine.execute("SELECT * FROM freecodecamp").fetchall()
# Out:
# [(0, 30220059, None, None, 'en', '2012-05-02T09:59:20Z', None, 'ESL_SC2', 135394, 'StarCraft II', 'en', 'https://static-cdn.jtvnw.net/jtv_user_pictures/esl_sc2-profile_image-d6db9488cec97125-300x300.jpeg', 0, 'esl_sc2', 1, 'https://static-cdn.jtvnw.net/jtv_user_pictures/esl_sc2-profile_banner-f8295b33d1846e75-480.jpeg', '#050506', 'RERUN: StarCraft 2 - Terminator vs. Parting (PvP) - IEM Katowice 2015 - EU Qualifier', '2016-10-10T22:04:21Z', 'https://www.twitch.tv/esl_sc2', 'https://static-cdn.jtvnw.net/jtv_user_pictures/esl_sc2-channel_offline_image-5a8657f8393c9d85-1920x1080.jpeg', 60991791, 'https://api.twitch.tv/kraken/chat/esl_sc2', 'https://api.twitch.tv/kraken/chat/esl_sc2', 'https://api.twitch.tv/kraken/channels/esl_sc2/commercial', 'https://api.twitch.tv/kraken/channels/esl_sc2/editors', 'https://api.twitch.tv/kraken/channels/esl_sc2/follows', 'https://api.twitch.tv/kraken/channels/esl_sc2', 'https://api.twitch.tv/kraken/channels/esl_sc2/stream_key', 'https://api.twitch.tv/kr
# ...

# %%
df.to_csv('output.csv',index=False)

# %% [markdown]
# Saved the output to a csv file
